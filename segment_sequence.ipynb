# %%
# Importet
import numpy as np
import pandas as pd

# %% [markdown]
# # Utforskning av datasets #

# %%
# Hämta datan från npz filen - allow 
sequence = np.load('segment_sequences.npz')

# Se vad som finns i filen
print(sequence.files)
# Out:
# ['X_seq', 'y_seq', 'groups', 'segment_id']

# %%
# Läs in csv-filen features för att utforska. 
df_features = pd.read_csv('segment_features.csv', sep=None, engine='python')

# Visa de första raderna så man får en överblick
df_features.head()
# Out:
#    segment_id  user_id           file_name  mode  n_points  duration_s  \
# 0           0       10  20080331160008.plt   car        10       533.0
# 1           1       10  20080331160008.plt   car        12       651.0
# 2           2       10  20080402060926.plt  walk       563      1139.0
# 3           3       10  20080402060926.plt   car       175       203.0
# 4           4       10  20080402060926.plt   bus       266      1584.0
#
#     distance_m  avg_speed_mps  max_speed_mps  std_speed_mps  ...  \
# 0  4997.940935       8.432578      13.554139       4.878132  ...
# 1  6031.302622       8.480828      19.759260       6.057875  ...
# 2   755.418664       1.083157       3.848027       0.478953  ...
# 3  1073.949583       5.936181      12.483375       3.656538  ...
# 4  7326.510691       6.984778      16.513127       3.722160  ...
#
#    p90_speed_mps  avg_acc_mps2  std_acc_mps2  max_acc_mps2  min_acc_mps2  \
# 0      12.967964      0.015542      0.120639      0.209189     -0.223434
# 1      15.047145      0.004020      0.118478      0.256099     -0.202980
# 2       1.492055      0.010578      0.458360      2.223425     -2.384665
# 3      10.732234      0.073373      0.735080      2.943170     -2.004067
# 4      11.717630      0.078682      1.053435      6.402394     -5.108211
#
#    avg_turn_deg  std_turn_deg  stop_ratio  high_speed_ratio  mid_speed_ratio
# 0      9.418788     23.030978    0.200000          0.500000         0.100000
# 1     35.872241     45.273584    0.083333          0.416667         0.500000
# 2     15.181143     15.664126    0.072824          0.000000         0.047957
# 3      7.713667      9.935911    0.040000          0.211429         0.468571
# 4      6.752381     17.676938    0.045113          0.251880         0.481203
#
# [5 rows x 21 columns]

# %%
# Läs in csv-filen metadata för att utforska. 
df_metadata = pd.read_csv('segment_metadata.csv', sep=None, engine='python')

# Visa de första raderna så man får en överblick
df_metadata.head()
# Out:
#    segment_id  user_id           file_name  mode
# 0           0       10  20080331160008.plt   car
# 1           1       10  20080331160008.plt   car
# 2           2       10  20080402060926.plt  walk
# 3           3       10  20080402060926.plt   car
# 4           4       10  20080402060926.plt   bus

# %% [markdown]
# ### Kommentar ###
#
# **.npz filen:**  Vet inte om vi behöver den? Vet inte riktigt hur man ska göra med den datan eller hur man använder den?
#
# **feature filen:** Här har vi all data vi behöver. features, targets(mode) och ev all userId:s och segmentsID:s.
#
# **metadata filen:** Här har vi samma data som i featuredatan förutom alla features. Vi behöver kanske inte denna fil heller?

# %% [markdown]
# # Task 1: Feature engineering and Machine Learning Model #
